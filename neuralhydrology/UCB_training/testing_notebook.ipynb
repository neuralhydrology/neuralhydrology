# %%
import sys
sys.path.append('/Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/')
from UCB_train import UCB_trainer
from pathlib import Path
import matplotlib.pyplot as plt
from neuralhydrology.evaluation.metrics import calculate_all_metrics
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
path_to_csv = Path('/Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/UCB_training')
params = {'learning_rate': 0.001, 'batch_size': 256, 'epochs': 1, 'validate_every': 1, 'save_weights_every': 1}
num_ensemble_members = 1
trainer = UCB_trainer(path_to_csv, params, num_ensemble_members)

# %%
trainer.train()
# Out:
# 2024-10-16 14:03:21,627: Logging to /Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_1610_140321/output.log initialized.
# 2024-10-16 14:03:21,628: ### Folder structure created at /Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_1610_140321
# 2024-10-16 14:03:21,628: ### Run configurations for testing_run
# 2024-10-16 14:03:21,629: experiment_name: testing_run
# 2024-10-16 14:03:21,630: train_basin_file: train_basin_file_template
# 2024-10-16 14:03:21,630: validation_basin_file: train_basin_file_template
# 2024-10-16 14:03:21,631: test_basin_file: train_basin_file_template
# 2024-10-16 14:03:21,633: train_start_date: 1981-10-01 00:00:00
# 2024-10-16 14:03:21,633: train_end_date: 1997-09-30 00:00:00
# 2024-10-16 14:03:21,634: validation_start_date: 1997-10-01 00:00:00
# 2024-10-16 14:03:21,634: validation_end_date: 2000-09-30 00:00:00
# 2024-10-16 14:03:21,635: test_start_date: 2000-10-01 00:00:00
# 2024-10-16 14:03:21,635: test_end_date: 2005-09-30 00:00:00
# 2024-10-16 14:03:21,636: device: cpu
# 2024-10-16 14:03:21,636: validate_every: 1
# 2024-10-16 14:03:21,637: validate_n_random_basins: 1
# 2024-10-16 14:03:21,637: metrics: ['NSE', 'MSE']
# 2024-10-16 14:03:21,638: model: cudalstm
# 2024-10-16 14:03:21,638: head: regression
# 2024-10-16 14:03:21,638: output_activation: linear
# 2024-10-16 14:03:21,639: hidden_size: 64
# 2024-10-16 14:03:21,641: initial_forget_bias: 3
# 2024-10-16 14:03:21,642: output_dropout: 0.5
# 2024-10-16 14:03:21,644: optimizer: Adam
# 2024-10-16 14:03:21,644: loss: MSE
# 2024-10-16 14:03:21,646: learning_rate: 0.001
# 2024-10-16 14:03:21,648: batch_size: 256
# 2024-10-16 14:03:21,649: epochs: 1
# 2024-10-16 14:03:21,650: clip_gradient_norm: 1
# 2024-10-16 14:03:21,651: predict_last_n: 1
# 2024-10-16 14:03:21,651: seq_length: 365
# 2024-10-16 14:03:21,651: num_workers: 8
# 2024-10-16 14:03:21,652: log_interval: 4
# 2024-10-16 14:03:21,652: log_tensorboard: True
# 2024-10-16 14:03:21,653: log_n_figures: 1
# 2024-10-16 14:03:21,653: save_weights_every: 1
# 2024-10-16 14:03:21,654: dataset: tuler
# 2024-10-16 14:03:21,654: data_dir: /Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/UCB_training
# 2024-10-16 14:03:21,654: dynamic_inputs: ['MF_TuleR_S10ET-POTENTIAL', 'MF_TuleR_S10FLOW', 'MF_TuleR_S10PRECIP-INC', 'MF_TuleR_S10SATURATION FRACTION', 'MF_TuleR_S10STORAGE-SOIL', 'MF_TuleR_S10SWE-OBSERVED', 'MF_TuleR_S10TEMPERATURE-AIR', 'MF_TuleR_S20ET-POTENTIAL', 'MF_TuleR_S20FLOW', 'MF_TuleR_S20PRECIP-INC', 'MF_TuleR_S20SATURATION FRACTION', 'MF_TuleR_S20STORAGE-SOIL', 'MF_TuleR_S20SWE-OBSERVED', 'MF_TuleR_S20TEMPERATURE-AIR', 'NF_TuleR_S10ET-POTENTIAL', 'NF_TuleR_S10FLOW', 'NF_TuleR_S10PRECIP-INC', 'NF_TuleR_S10SATURATION FRACTION', 'NF_TuleR_S10STORAGE-SOIL', 'NF_TuleR_S10SWE-OBSERVED', 'NF_TuleR_S10TEMPERATURE-AIR', 'ReservoirInflowFLOW', 'SF_TuleR_S10ET-POTENTIAL', 'SF_TuleR_S10FLOW', 'SF_TuleR_S10PRECIP-INC', 'SF_TuleR_S10SATURATION FRACTION', 'SF_TuleR_S10STORAGE-SOIL', 'SF_TuleR_S10SWE-OBSERVED', 'SF_TuleR_S10TEMPERATURE-AIR', 'TuleR_S10ET-POTENTIAL', 'TuleR_S10FLOW', 'TuleR_S10PRECIP-INC', 'TuleR_S10SATURATION FRACTION', 'TuleR_S10STORAGE-SOIL', 'TuleR_S10TEMPERATURE-AIR', 'TuleR_S20ET-POTENTIAL', 'TuleR_S20FLOW', 'TuleR_S20PRECIP-INC', 'TuleR_S20SATURATION FRACTION', 'TuleR_S20STORAGE-SOIL', 'TuleR_S20SWE-OBSERVED', 'TuleR_S20TEMPERATURE-AIR']
# 2024-10-16 14:03:21,655: target_variables: ['ReservoirInflowFLOW-OBSERVED']
# 2024-10-16 14:03:21,655: number_of_basins: 1
# 2024-10-16 14:03:21,656: run_dir: /Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_1610_140321
# 2024-10-16 14:03:21,656: train_dir: /Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_1610_140321/train_data
# 2024-10-16 14:03:21,657: img_log_dir: /Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_1610_140321/img_log
# 2024-10-16 14:03:21,665: ### Device cpu will be used for training
# 2024-10-16 14:03:21,667: Loading basin data into xarray data set.
# 100%|██████████| 1/1 [00:00<00:00,  9.75it/s]
# 2024-10-16 14:03:21,968: Create lookup table and convert to pytorch tensor
# 100%|██████████| 1/1 [00:01<00:00,  1.67s/it]
# # Epoch 1:   0%|          | 0/22 [00:00<?, ?it/s]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:   5%|▍         | 1/22 [00:22<07:45, 22.18s/it, Loss: 0.4647]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:   9%|▉         | 2/22 [00:22<03:07,  9.38s/it, Loss: 0.4501]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  14%|█▎        | 3/22 [00:23<01:40,  5.28s/it, Loss: 0.2472]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  18%|█▊        | 4/22 [00:23<01:00,  3.36s/it, Loss: 0.3869]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  23%|██▎       | 5/22 [00:23<00:39,  2.30s/it, Loss: 0.1586]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  27%|██▋       | 6/22 [00:24<00:26,  1.64s/it, Loss: 0.2737]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  32%|███▏      | 7/22 [00:24<00:18,  1.23s/it, Loss: 0.3618]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  36%|███▋      | 8/22 [00:25<00:13,  1.02it/s, Loss: 0.0979]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  41%|████      | 9/22 [00:25<00:10,  1.27it/s, Loss: 0.2821]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  45%|████▌     | 10/22 [00:25<00:08,  1.47it/s, Loss: 0.1041]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  50%|█████     | 11/22 [00:26<00:06,  1.70it/s, Loss: 0.1785]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  55%|█████▍    | 12/22 [00:26<00:05,  1.85it/s, Loss: 0.2383]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  59%|█████▉    | 13/22 [00:27<00:04,  1.82it/s, Loss: 0.2089]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  64%|██████▎   | 14/22 [00:27<00:03,  2.00it/s, Loss: 0.1870]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  68%|██████▊   | 15/22 [00:27<00:03,  2.17it/s, Loss: 0.2539]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  73%|███████▎  | 16/22 [00:28<00:02,  2.31it/s, Loss: 0.4002]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  77%|███████▋  | 17/22 [00:28<00:02,  2.37it/s, Loss: 0.1919]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  82%|████████▏ | 18/22 [00:29<00:01,  2.38it/s, Loss: 0.9496]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  86%|████████▋ | 19/22 [00:29<00:01,  2.47it/s, Loss: 0.3812]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  91%|█████████ | 20/22 [00:29<00:00,  2.53it/s, Loss: 0.1466]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  95%|█████████▌| 21/22 [00:30<00:00,  2.58it/s, Loss: 0.4204]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1: 100%|██████████| 22/22 [00:31<00:00,  1.44s/it, Loss: 0.8112]
# 2024-10-16 14:03:57,013: Epoch 1 average loss: avg_loss: 0.32705, avg_total_loss: 0.32705
# # Validation: 100%|██████████| 1/1 [00:01<00:00,  1.22s/it]
# 2024-10-16 14:03:58,859: Epoch 1 average validation loss: 0.14144 -- Median validation metrics: avg_loss: 0.14144, NSE: 0.67700, MSE: 66988.82031
# 2024-10-16 14:03:58,884: Using the model weights from /Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_1610_140321/model_epoch001.pt
# # Evaluation: 100%|██████████| 1/1 [00:01<00:00,  1.10s/it]
# 2024-10-16 14:03:59,995: Stored metrics at /Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_1610_140321/test/model_epoch001/test_metrics.csv
# 2024-10-16 14:03:59,996: Stored results at /Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_1610_140321/test/model_epoch001/test_results.p

# %%
trainer.results()
# Out:
# {'NSE': 0.16198396682739258,
#  'MSE': 42972.0,
#  'RMSE': 207.29688854394317,
#  'KGE': 0.4688209599496489,
#  'Alpha-NSE': 0.8578235359360687,
#  'Beta-KGE': 1.2084088325500488,
#  'Beta-NSE': 0.125836245533993,
#  'Pearson-r': 0.5325571862032576,
#  'FHV': -39.181870222091675,
#  'FMS': 106.70396705720633,
#  'FLV': -135.51731511083455,
#  'Peak-Timing': 1.0,
#  'Peak-MAPE': 48.210763931274414}

# %%
# .311

# %%
path_to_csv = Path('/Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/UCB_training')
params = {'learning_rate': 0.001, 'batch_size': 256, 'epochs': 1, 'validate_every': 1, 'save_weights_every': 1}
num_ensemble_members = 2
trainer = UCB_trainer(path_to_csv, params, num_ensemble_members)

# %%
trainer.train()
# Out:
# 2024-10-16 14:04:48,619: Logging to /Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_1610_140448/output.log initialized.
# 2024-10-16 14:04:48,620: ### Folder structure created at /Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_1610_140448
# 2024-10-16 14:04:48,621: ### Run configurations for testing_run
# 2024-10-16 14:04:48,621: experiment_name: testing_run
# 2024-10-16 14:04:48,622: train_basin_file: train_basin_file_template
# 2024-10-16 14:04:48,623: validation_basin_file: train_basin_file_template
# 2024-10-16 14:04:48,624: test_basin_file: train_basin_file_template
# 2024-10-16 14:04:48,625: train_start_date: 1981-10-01 00:00:00
# 2024-10-16 14:04:48,625: train_end_date: 1997-09-30 00:00:00
# 2024-10-16 14:04:48,626: validation_start_date: 1997-10-01 00:00:00
# 2024-10-16 14:04:48,626: validation_end_date: 2000-09-30 00:00:00
# 2024-10-16 14:04:48,626: test_start_date: 2000-10-01 00:00:00
# 2024-10-16 14:04:48,627: test_end_date: 2005-09-30 00:00:00
# 2024-10-16 14:04:48,627: device: cpu
# 2024-10-16 14:04:48,627: validate_every: 1
# 2024-10-16 14:04:48,628: validate_n_random_basins: 1
# 2024-10-16 14:04:48,628: metrics: ['NSE', 'MSE']
# 2024-10-16 14:04:48,629: model: cudalstm
# 2024-10-16 14:04:48,629: head: regression
# 2024-10-16 14:04:48,629: output_activation: linear
# 2024-10-16 14:04:48,630: hidden_size: 64
# 2024-10-16 14:04:48,630: initial_forget_bias: 3
# 2024-10-16 14:04:48,630: output_dropout: 0.5
# 2024-10-16 14:04:48,631: optimizer: Adam
# 2024-10-16 14:04:48,631: loss: MSE
# 2024-10-16 14:04:48,632: learning_rate: 0.001
# 2024-10-16 14:04:48,632: batch_size: 256
# 2024-10-16 14:04:48,632: epochs: 1
# 2024-10-16 14:04:48,633: clip_gradient_norm: 1
# 2024-10-16 14:04:48,633: predict_last_n: 1
# 2024-10-16 14:04:48,633: seq_length: 365
# 2024-10-16 14:04:48,634: num_workers: 8
# 2024-10-16 14:04:48,634: log_interval: 4
# 2024-10-16 14:04:48,635: log_tensorboard: True
# 2024-10-16 14:04:48,635: log_n_figures: 1
# 2024-10-16 14:04:48,635: save_weights_every: 1
# 2024-10-16 14:04:48,636: dataset: tuler
# 2024-10-16 14:04:48,636: data_dir: /Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/UCB_training
# 2024-10-16 14:04:48,636: dynamic_inputs: ['MF_TuleR_S10ET-POTENTIAL', 'MF_TuleR_S10FLOW', 'MF_TuleR_S10PRECIP-INC', 'MF_TuleR_S10SATURATION FRACTION', 'MF_TuleR_S10STORAGE-SOIL', 'MF_TuleR_S10SWE-OBSERVED', 'MF_TuleR_S10TEMPERATURE-AIR', 'MF_TuleR_S20ET-POTENTIAL', 'MF_TuleR_S20FLOW', 'MF_TuleR_S20PRECIP-INC', 'MF_TuleR_S20SATURATION FRACTION', 'MF_TuleR_S20STORAGE-SOIL', 'MF_TuleR_S20SWE-OBSERVED', 'MF_TuleR_S20TEMPERATURE-AIR', 'NF_TuleR_S10ET-POTENTIAL', 'NF_TuleR_S10FLOW', 'NF_TuleR_S10PRECIP-INC', 'NF_TuleR_S10SATURATION FRACTION', 'NF_TuleR_S10STORAGE-SOIL', 'NF_TuleR_S10SWE-OBSERVED', 'NF_TuleR_S10TEMPERATURE-AIR', 'ReservoirInflowFLOW', 'SF_TuleR_S10ET-POTENTIAL', 'SF_TuleR_S10FLOW', 'SF_TuleR_S10PRECIP-INC', 'SF_TuleR_S10SATURATION FRACTION', 'SF_TuleR_S10STORAGE-SOIL', 'SF_TuleR_S10SWE-OBSERVED', 'SF_TuleR_S10TEMPERATURE-AIR', 'TuleR_S10ET-POTENTIAL', 'TuleR_S10FLOW', 'TuleR_S10PRECIP-INC', 'TuleR_S10SATURATION FRACTION', 'TuleR_S10STORAGE-SOIL', 'TuleR_S10TEMPERATURE-AIR', 'TuleR_S20ET-POTENTIAL', 'TuleR_S20FLOW', 'TuleR_S20PRECIP-INC', 'TuleR_S20SATURATION FRACTION', 'TuleR_S20STORAGE-SOIL', 'TuleR_S20SWE-OBSERVED', 'TuleR_S20TEMPERATURE-AIR']
# 2024-10-16 14:04:48,637: target_variables: ['ReservoirInflowFLOW-OBSERVED']
# 2024-10-16 14:04:48,637: number_of_basins: 1
# 2024-10-16 14:04:48,637: run_dir: /Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_1610_140448
# 2024-10-16 14:04:48,638: train_dir: /Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_1610_140448/train_data
# 2024-10-16 14:04:48,638: img_log_dir: /Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_1610_140448/img_log
# 2024-10-16 14:04:48,648: ### Device cpu will be used for training
# 2024-10-16 14:04:48,648: Loading basin data into xarray data set.
# 100%|██████████| 1/1 [00:00<00:00,  9.53it/s]
# 2024-10-16 14:04:48,786: Create lookup table and convert to pytorch tensor
# 100%|██████████| 1/1 [00:00<00:00,  5.26it/s]
# # Epoch 1:   0%|          | 0/22 [00:00<?, ?it/s]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:   5%|▍         | 1/22 [00:21<07:36, 21.76s/it, Loss: 0.6461]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:   9%|▉         | 2/22 [00:22<03:03,  9.20s/it, Loss: 0.3978]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  14%|█▎        | 3/22 [00:22<01:38,  5.21s/it, Loss: 0.9458]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  18%|█▊        | 4/22 [00:23<00:59,  3.32s/it, Loss: 0.6109]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  23%|██▎       | 5/22 [00:23<00:38,  2.26s/it, Loss: 0.1652]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  27%|██▋       | 6/22 [00:23<00:25,  1.62s/it, Loss: 0.2827]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  32%|███▏      | 7/22 [00:24<00:18,  1.22s/it, Loss: 0.2007]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  36%|███▋      | 8/22 [00:24<00:13,  1.05it/s, Loss: 0.6707]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  41%|████      | 9/22 [00:25<00:10,  1.27it/s, Loss: 0.2433]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  45%|████▌     | 10/22 [00:25<00:07,  1.52it/s, Loss: 0.3749]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  50%|█████     | 11/22 [00:25<00:06,  1.71it/s, Loss: 0.3170]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  55%|█████▍    | 12/22 [00:26<00:05,  1.89it/s, Loss: 0.1809]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  59%|█████▉    | 13/22 [00:26<00:04,  2.05it/s, Loss: 0.1524]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  64%|██████▎   | 14/22 [00:26<00:03,  2.20it/s, Loss: 0.3901]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  68%|██████▊   | 15/22 [00:27<00:03,  2.20it/s, Loss: 0.4187]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  73%|███████▎  | 16/22 [00:27<00:02,  2.33it/s, Loss: 0.1530]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  77%|███████▋  | 17/22 [00:28<00:02,  2.39it/s, Loss: 0.1805]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  82%|████████▏ | 18/22 [00:28<00:01,  2.29it/s, Loss: 0.1564]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  86%|████████▋ | 19/22 [00:29<00:01,  2.32it/s, Loss: 0.2260]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  91%|█████████ | 20/22 [00:29<00:00,  2.25it/s, Loss: 0.0856]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  95%|█████████▌| 21/22 [00:29<00:00,  2.36it/s, Loss: 0.1903]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1: 100%|██████████| 22/22 [00:31<00:00,  1.45s/it, Loss: 0.0744]
# 2024-10-16 14:05:20,932: Epoch 1 average loss: avg_loss: 0.32105, avg_total_loss: 0.32105
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  1.37it/s]
# 2024-10-16 14:05:21,886: Epoch 1 average validation loss: 0.12442 -- Median validation metrics: avg_loss: 0.12442, NSE: 0.71583, MSE: 58936.32031
# 2024-10-16 14:05:21,889: Logging to /Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_1610_140448/testing_run_1610_140521/output.log initialized.
# 2024-10-16 14:05:21,890: ### Folder structure created at /Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_1610_140448/testing_run_1610_140521
# 2024-10-16 14:05:21,890: ### Run configurations for testing_run
# 2024-10-16 14:05:21,891: experiment_name: testing_run
# 2024-10-16 14:05:21,891: train_basin_file: train_basin_file_template
# 2024-10-16 14:05:21,892: validation_basin_file: train_basin_file_template
# 2024-10-16 14:05:21,893: test_basin_file: train_basin_file_template
# 2024-10-16 14:05:21,893: train_start_date: 1981-10-01 00:00:00
# 2024-10-16 14:05:21,894: train_end_date: 1997-09-30 00:00:00
# 2024-10-16 14:05:21,894: validation_start_date: 1997-10-01 00:00:00
# 2024-10-16 14:05:21,895: validation_end_date: 2000-09-30 00:00:00
# 2024-10-16 14:05:21,895: test_start_date: 2000-10-01 00:00:00
# 2024-10-16 14:05:21,895: test_end_date: 2005-09-30 00:00:00
# 2024-10-16 14:05:21,896: device: cpu
# 2024-10-16 14:05:21,896: validate_every: 1
# 2024-10-16 14:05:21,896: validate_n_random_basins: 1
# 2024-10-16 14:05:21,897: metrics: ['NSE', 'MSE']
# 2024-10-16 14:05:21,897: model: cudalstm
# 2024-10-16 14:05:21,898: head: regression
# 2024-10-16 14:05:21,898: output_activation: linear
# 2024-10-16 14:05:21,898: hidden_size: 64
# 2024-10-16 14:05:21,899: initial_forget_bias: 3
# 2024-10-16 14:05:21,899: output_dropout: 0.5
# 2024-10-16 14:05:21,900: optimizer: Adam
# 2024-10-16 14:05:21,900: loss: MSE
# 2024-10-16 14:05:21,900: learning_rate: 0.001
# 2024-10-16 14:05:21,901: batch_size: 256
# 2024-10-16 14:05:21,901: epochs: 1
# 2024-10-16 14:05:21,902: clip_gradient_norm: 1
# 2024-10-16 14:05:21,903: predict_last_n: 1
# 2024-10-16 14:05:21,904: seq_length: 365
# 2024-10-16 14:05:21,904: num_workers: 8
# 2024-10-16 14:05:21,904: log_interval: 4
# 2024-10-16 14:05:21,905: log_tensorboard: True
# 2024-10-16 14:05:21,905: log_n_figures: 1
# 2024-10-16 14:05:21,907: save_weights_every: 1
# 2024-10-16 14:05:21,907: dataset: tuler
# 2024-10-16 14:05:21,907: data_dir: /Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/UCB_training
# 2024-10-16 14:05:21,908: dynamic_inputs: ['MF_TuleR_S10ET-POTENTIAL', 'MF_TuleR_S10FLOW', 'MF_TuleR_S10PRECIP-INC', 'MF_TuleR_S10SATURATION FRACTION', 'MF_TuleR_S10STORAGE-SOIL', 'MF_TuleR_S10SWE-OBSERVED', 'MF_TuleR_S10TEMPERATURE-AIR', 'MF_TuleR_S20ET-POTENTIAL', 'MF_TuleR_S20FLOW', 'MF_TuleR_S20PRECIP-INC', 'MF_TuleR_S20SATURATION FRACTION', 'MF_TuleR_S20STORAGE-SOIL', 'MF_TuleR_S20SWE-OBSERVED', 'MF_TuleR_S20TEMPERATURE-AIR', 'NF_TuleR_S10ET-POTENTIAL', 'NF_TuleR_S10FLOW', 'NF_TuleR_S10PRECIP-INC', 'NF_TuleR_S10SATURATION FRACTION', 'NF_TuleR_S10STORAGE-SOIL', 'NF_TuleR_S10SWE-OBSERVED', 'NF_TuleR_S10TEMPERATURE-AIR', 'ReservoirInflowFLOW', 'SF_TuleR_S10ET-POTENTIAL', 'SF_TuleR_S10FLOW', 'SF_TuleR_S10PRECIP-INC', 'SF_TuleR_S10SATURATION FRACTION', 'SF_TuleR_S10STORAGE-SOIL', 'SF_TuleR_S10SWE-OBSERVED', 'SF_TuleR_S10TEMPERATURE-AIR', 'TuleR_S10ET-POTENTIAL', 'TuleR_S10FLOW', 'TuleR_S10PRECIP-INC', 'TuleR_S10SATURATION FRACTION', 'TuleR_S10STORAGE-SOIL', 'TuleR_S10TEMPERATURE-AIR', 'TuleR_S20ET-POTENTIAL', 'TuleR_S20FLOW', 'TuleR_S20PRECIP-INC', 'TuleR_S20SATURATION FRACTION', 'TuleR_S20STORAGE-SOIL', 'TuleR_S20SWE-OBSERVED', 'TuleR_S20TEMPERATURE-AIR']
# 2024-10-16 14:05:21,909: target_variables: ['ReservoirInflowFLOW-OBSERVED']
# 2024-10-16 14:05:21,909: number_of_basins: 1
# 2024-10-16 14:05:21,909: run_dir: /Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_1610_140448/testing_run_1610_140521
# 2024-10-16 14:05:21,910: train_dir: /Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_1610_140448/testing_run_1610_140521/train_data
# 2024-10-16 14:05:21,911: img_log_dir: /Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_1610_140448/testing_run_1610_140521/img_log
# 2024-10-16 14:05:21,911: seed: 375246
# 2024-10-16 14:05:21,912: commit_hash: 5222394
# 2024-10-16 14:05:21,913: package_version: 1.11.0
# 2024-10-16 14:05:21,921: ### Device cpu will be used for training
# 2024-10-16 14:05:21,923: Loading basin data into xarray data set.
# 100%|██████████| 1/1 [00:00<00:00,  8.20it/s]
# 2024-10-16 14:05:22,064: Create lookup table and convert to pytorch tensor
# 100%|██████████| 1/1 [00:00<00:00,  5.17it/s]
# # Epoch 1:   0%|          | 0/22 [00:00<?, ?it/s]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:   5%|▍         | 1/22 [00:21<07:30, 21.44s/it, Loss: 0.6461]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:   9%|▉         | 2/22 [00:21<03:01,  9.09s/it, Loss: 0.3978]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  14%|█▎        | 3/22 [00:22<01:37,  5.11s/it, Loss: 0.9458]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  18%|█▊        | 4/22 [00:22<00:58,  3.24s/it, Loss: 0.6109]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  23%|██▎       | 5/22 [00:23<00:37,  2.21s/it, Loss: 0.1652]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  27%|██▋       | 6/22 [00:23<00:25,  1.59s/it, Loss: 0.2827]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  32%|███▏      | 7/22 [00:23<00:17,  1.19s/it, Loss: 0.2007]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  36%|███▋      | 8/22 [00:24<00:13,  1.06it/s, Loss: 0.6707]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  41%|████      | 9/22 [00:24<00:09,  1.32it/s, Loss: 0.2433]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  45%|████▌     | 10/22 [00:25<00:07,  1.50it/s, Loss: 0.3749]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  50%|█████     | 11/22 [00:25<00:07,  1.53it/s, Loss: 0.3170]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  55%|█████▍    | 12/22 [00:26<00:05,  1.67it/s, Loss: 0.1809]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  59%|█████▉    | 13/22 [00:26<00:04,  1.84it/s, Loss: 0.1524]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  64%|██████▎   | 14/22 [00:26<00:03,  2.02it/s, Loss: 0.3901]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  68%|██████▊   | 15/22 [00:27<00:03,  2.18it/s, Loss: 0.4187]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  73%|███████▎  | 16/22 [00:27<00:02,  2.32it/s, Loss: 0.1530]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  77%|███████▋  | 17/22 [00:28<00:02,  2.39it/s, Loss: 0.1805]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  82%|████████▏ | 18/22 [00:28<00:01,  2.45it/s, Loss: 0.1564]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  86%|████████▋ | 19/22 [00:28<00:01,  2.45it/s, Loss: 0.2260]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  91%|█████████ | 20/22 [00:29<00:00,  2.52it/s, Loss: 0.0856]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  95%|█████████▌| 21/22 [00:29<00:00,  2.55it/s, Loss: 0.1903]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1: 100%|██████████| 22/22 [00:31<00:00,  1.41s/it, Loss: 0.0744]
# 2024-10-16 14:05:53,526: Epoch 1 average loss: avg_loss: 0.32105, avg_total_loss: 0.32105
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  1.27it/s]
# 2024-10-16 14:05:54,524: Epoch 1 average validation loss: 0.12442 -- Median validation metrics: avg_loss: 0.12442, NSE: 0.71583, MSE: 58936.32031
# 2024-10-16 14:05:54,546: Using the model weights from /Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_1610_140448/model_epoch001.pt
# # Evaluation: 100%|██████████| 1/1 [00:01<00:00,  1.11s/it]
# 2024-10-16 14:05:55,671: Stored metrics at /Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_1610_140448/test/model_epoch001/test_metrics.csv
# 2024-10-16 14:05:55,672: Stored results at /Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_1610_140448/test/model_epoch001/test_results.p
# 2024-10-16 14:05:55,693: Using the model weights from /Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_1610_140448/testing_run_1610_140521/model_epoch001.pt
# # Evaluation: 100%|██████████| 1/1 [00:01<00:00,  1.07s/it]
# 2024-10-16 14:05:56,764: Stored metrics at /Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_1610_140448/testing_run_1610_140521/test/model_epoch001/test_metrics.csv
# 2024-10-16 14:05:56,765: Stored results at /Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_1610_140448/testing_run_1610_140521/test/model_epoch001/test_results.p
# Loading results for each run.
# 100%|██████████| 2/2 [00:00<00:00, 1137.44it/s]
# Combining results and calculating metrics.
# 100%|██████████| 1/1 [00:00<00:00, 100.88it/s]

# %%
trainer.results()
# Out:
# {'NSE': 0.316394567489624,
#  'MSE': 35054.09375,
#  'RMSE': 187.22738514971576,
#  'KGE': 0.4437249747468549,
#  'Alpha-NSE': 0.6524060138925819,
#  'Beta-KGE': 0.9416107535362244,
#  'Beta-NSE': -0.035255158911077965,
#  'Pearson-r': 0.5696385002817566,
#  'FHV': -48.860761523246765,
#  'FMS': -7.004293077846866,
#  'FLV': -408.5565918767156,
#  'Peak-Timing': 0.42857142857142855,
#  'Peak-MAPE': 58.24798175266811}

# %%
trainer.test
