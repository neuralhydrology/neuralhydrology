# %%
from UCB_train import UCB_trainer
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 from UCB_train import UCB_trainer
#
# File ~/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/UCB_training/UCB_train.py:20
#      <a href='file:///Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/UCB_training/UCB_train.py?line=17'>18</a> from neuralhydrology.datasetzoo.basedataset import BaseDataset
#      <a href='file:///Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/UCB_training/UCB_train.py?line=18'>19</a> from neuralhydrology.utils.config import Config
# ---> <a href='file:///Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/UCB_training/UCB_train.py?line=19'>20</a> from neuralhydrology.training.train import start_training
#      <a href='file:///Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/UCB_training/UCB_train.py?line=20'>21</a> from neuralhydrology.nh_run import eval_run
#      <a href='file:///Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/UCB_training/UCB_train.py?line=21'>22</a> from neuralhydrology.utils.nh_results_ensemble import create_results_ensemble
#
# File ~/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/training/train.py:1
# ----> <a href='file:///Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/training/train.py?line=0'>1</a> from neuralhydrology.training.basetrainer import BaseTrainer
#       <a href='file:///Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/training/train.py?line=1'>2</a> from neuralhydrology.utils.config import Config
#       <a href='file:///Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/training/train.py?line=4'>5</a> def start_training(cfg: Config):
#
# File ~/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/training/basetrainer.py:18
#      <a href='file:///Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/training/basetrainer.py?line=15'>16</a> from neuralhydrology.datasetzoo.basedataset import BaseDataset
#      <a href='file:///Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/training/basetrainer.py?line=16'>17</a> from neuralhydrology.datautils.utils import load_basin_file, load_scaler
# ---> <a href='file:///Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/training/basetrainer.py?line=17'>18</a> from neuralhydrology.evaluation import get_tester
#      <a href='file:///Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/training/basetrainer.py?line=18'>19</a> from neuralhydrology.evaluation.tester import BaseTester
#      <a href='file:///Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/training/basetrainer.py?line=19'>20</a> from neuralhydrology.modelzoo import get_model
#
# File ~/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/evaluation/__init__.py:3
#       <a href='file:///Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/evaluation/__init__.py?line=0'>1</a> from pathlib import Path
# ----> <a href='file:///Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/evaluation/__init__.py?line=2'>3</a> from neuralhydrology.evaluation.tester import BaseTester, RegressionTester, UncertaintyTester
#       <a href='file:///Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/evaluation/__init__.py?line=3'>4</a> from neuralhydrology.utils.config import Config
#       <a href='file:///Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/evaluation/__init__.py?line=6'>7</a> def get_tester(cfg: Config, run_dir: Path, period: str, init_model: bool) -> BaseTester:
#
# File ~/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/evaluation/tester.py:21
#      <a href='file:///Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/evaluation/tester.py?line=18'>19</a> from neuralhydrology.datautils.utils import get_frequency_factor, load_basin_file, load_scaler, sort_frequencies
#      <a href='file:///Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/evaluation/tester.py?line=19'>20</a> from neuralhydrology.evaluation import plots
# ---> <a href='file:///Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/evaluation/tester.py?line=20'>21</a> from neuralhydrology.evaluation.metrics import calculate_metrics, get_available_metrics
#      <a href='file:///Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/evaluation/tester.py?line=21'>22</a> from neuralhydrology.evaluation.utils import load_basin_id_encoding, metrics_to_dataframe
#      <a href='file:///Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/evaluation/tester.py?line=22'>23</a> from neuralhydrology.modelzoo import get_model
#
# File ~/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/evaluation/metrics.py:6
#       <a href='file:///Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/evaluation/metrics.py?line=3'>4</a> import numpy as np
#       <a href='file:///Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/evaluation/metrics.py?line=4'>5</a> import pandas as pd
# ----> <a href='file:///Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/evaluation/metrics.py?line=5'>6</a> from scipy import stats, signal
#       <a href='file:///Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/evaluation/metrics.py?line=6'>7</a> from xarray.core.dataarray import DataArray
#       <a href='file:///Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/evaluation/metrics.py?line=8'>9</a> from neuralhydrology.datautils import utils
#
# File <frozen importlib._bootstrap>:1075, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File ~/anaconda3/envs/ESDL_LSTM/lib/python3.10/site-packages/scipy/__init__.py:189, in __getattr__(name)
#     <a href='file:///Users/evanrobert/anaconda3/envs/ESDL_LSTM/lib/python3.10/site-packages/scipy/__init__.py?line=186'>187</a> def __getattr__(name):
#     <a href='file:///Users/evanrobert/anaconda3/envs/ESDL_LSTM/lib/python3.10/site-packages/scipy/__init__.py?line=187'>188</a>     if name in submodules:
# --> <a href='file:///Users/evanrobert/anaconda3/envs/ESDL_LSTM/lib/python3.10/site-packages/scipy/__init__.py?line=188'>189</a>         return _importlib.import_module(f'scipy.{name}')
#     <a href='file:///Users/evanrobert/anaconda3/envs/ESDL_LSTM/lib/python3.10/site-packages/scipy/__init__.py?line=189'>190</a>     else:
#     <a href='file:///Users/evanrobert/anaconda3/envs/ESDL_LSTM/lib/python3.10/site-packages/scipy/__init__.py?line=190'>191</a>         try:
#
# File ~/anaconda3/envs/ESDL_LSTM/lib/python3.10/importlib/__init__.py:126, in import_module(name, package)
#     <a href='file:///Users/evanrobert/anaconda3/envs/ESDL_LSTM/lib/python3.10/importlib/__init__.py?line=123'>124</a>             break
#     <a href='file:///Users/evanrobert/anaconda3/envs/ESDL_LSTM/lib/python3.10/importlib/__init__.py?line=124'>125</a>         level += 1
# --> <a href='file:///Users/evanrobert/anaconda3/envs/ESDL_LSTM/lib/python3.10/importlib/__init__.py?line=125'>126</a> return _bootstrap._gcd_import(name[level:], package, level)
#
# File ~/anaconda3/envs/ESDL_LSTM/lib/python3.10/site-packages/scipy/stats/__init__.py:608
#       <a href='file:///Users/evanrobert/anaconda3/envs/ESDL_LSTM/lib/python3.10/site-packages/scipy/stats/__init__.py?line=0'>1</a> """
#       <a href='file:///Users/evanrobert/anaconda3/envs/ESDL_LSTM/lib/python3.10/site-packages/scipy/stats/__init__.py?line=1'>2</a> .. _statsrefmanual:
#       <a href='file:///Users/evanrobert/anaconda3/envs/ESDL_LSTM/lib/python3.10/site-packages/scipy/stats/__init__.py?line=2'>3</a>
#    (...)
#     <a href='file:///Users/evanrobert/anaconda3/envs/ESDL_LSTM/lib/python3.10/site-packages/scipy/stats/__init__.py?line=602'>603</a>
#     <a href='file:///Users/evanrobert/anaconda3/envs/ESDL_LSTM/lib/python3.10/site-packages/scipy/stats/__init__.py?line=603'>604</a> """
#     <a href='file:///Users/evanrobert/anaconda3/envs/ESDL_LSTM/lib/python3.10/site-packages/scipy/stats/__init__.py?line=605'>606</a> from ._warnings_errors import (ConstantInputWarning, NearConstantInputWarning,
#     <a href='file:///Users/evanrobert/anaconda3/envs/ESDL_LSTM/lib/python3.10/site-packages/scipy/stats/__init__.py?line=606'>607</a>                                DegenerateDataWarning, FitError)
# --> <a href='file:///Users/evanrobert/anaconda3/envs/ESDL_LSTM/lib/python3.10/site-packages/scipy/stats/__init__.py?line=607'>608</a> from ._stats_py import *
#     <a href='file:///Users/evanrobert/anaconda3/envs/ESDL_LSTM/lib/python3.10/site-packages/scipy/stats/__init__.py?line=608'>609</a> from ._variation import variation
#     <a href='file:///Users/evanrobert/anaconda3/envs/ESDL_LSTM/lib/python3.10/site-packages/scipy/stats/__init__.py?line=609'>610</a> from .distributions import *
#
# File ~/anaconda3/envs/ESDL_LSTM/lib/python3.10/site-packages/scipy/stats/_stats_py.py:46
#      <a href='file:///Users/evanrobert/anaconda3/envs/ESDL_LSTM/lib/python3.10/site-packages/scipy/stats/_stats_py.py?line=43'>44</a> import scipy.special as special
#      <a href='file:///Users/evanrobert/anaconda3/envs/ESDL_LSTM/lib/python3.10/site-packages/scipy/stats/_stats_py.py?line=44'>45</a> from scipy import linalg
# ---> <a href='file:///Users/evanrobert/anaconda3/envs/ESDL_LSTM/lib/python3.10/site-packages/scipy/stats/_stats_py.py?line=45'>46</a> from . import distributions
#      <a href='file:///Users/evanrobert/anaconda3/envs/ESDL_LSTM/lib/python3.10/site-packages/scipy/stats/_stats_py.py?line=46'>47</a> from . import _mstats_basic as mstats_basic
#      <a href='file:///Users/evanrobert/anaconda3/envs/ESDL_LSTM/lib/python3.10/site-packages/scipy/stats/_stats_py.py?line=47'>48</a> from ._stats_mstats_common import (_find_repeats, linregress, theilslopes,
#      <a href='file:///Users/evanrobert/anaconda3/envs/ESDL_LSTM/lib/python3.10/site-packages/scipy/stats/_stats_py.py?line=48'>49</a>                                    siegelslopes)
#
# File ~/anaconda3/envs/ESDL_LSTM/lib/python3.10/site-packages/scipy/stats/distributions.py:10
#       <a href='file:///Users/evanrobert/anaconda3/envs/ESDL_LSTM/lib/python3.10/site-packages/scipy/stats/distributions.py?line=0'>1</a> #
#       <a href='file:///Users/evanrobert/anaconda3/envs/ESDL_LSTM/lib/python3.10/site-packages/scipy/stats/distributions.py?line=1'>2</a> # Author:  Travis Oliphant  2002-2011 with contributions from
#       <a href='file:///Users/evanrobert/anaconda3/envs/ESDL_LSTM/lib/python3.10/site-packages/scipy/stats/distributions.py?line=2'>3</a> #          SciPy Developers 2004-2011
#    (...)
#       <a href='file:///Users/evanrobert/anaconda3/envs/ESDL_LSTM/lib/python3.10/site-packages/scipy/stats/distributions.py?line=5'>6</a> #       instead of `git blame -Lxxx,+x`.
#       <a href='file:///Users/evanrobert/anaconda3/envs/ESDL_LSTM/lib/python3.10/site-packages/scipy/stats/distributions.py?line=6'>7</a> #
#       <a href='file:///Users/evanrobert/anaconda3/envs/ESDL_LSTM/lib/python3.10/site-packages/scipy/stats/distributions.py?line=7'>8</a> from ._distn_infrastructure import (rv_discrete, rv_continuous, rv_frozen)  # noqa: F401
# ---> <a href='file:///Users/evanrobert/anaconda3/envs/ESDL_LSTM/lib/python3.10/site-packages/scipy/stats/distributions.py?line=9'>10</a> from . import _continuous_distns
#      <a href='file:///Users/evanrobert/anaconda3/envs/ESDL_LSTM/lib/python3.10/site-packages/scipy/stats/distributions.py?line=10'>11</a> from . import _discrete_distns
#      <a href='file:///Users/evanrobert/anaconda3/envs/ESDL_LSTM/lib/python3.10/site-packages/scipy/stats/distributions.py?line=12'>13</a> from ._continuous_distns import *
#
# File ~/anaconda3/envs/ESDL_LSTM/lib/python3.10/site-packages/scipy/stats/_continuous_distns.py:33
#      <a href='file:///Users/evanrobert/anaconda3/envs/ESDL_LSTM/lib/python3.10/site-packages/scipy/stats/_continuous_distns.py?line=29'>30</a> from ._constants import (_XMIN, _LOGXMIN, _EULER, _ZETA3, _SQRT_PI,
#      <a href='file:///Users/evanrobert/anaconda3/envs/ESDL_LSTM/lib/python3.10/site-packages/scipy/stats/_continuous_distns.py?line=30'>31</a>                          _SQRT_2_OVER_PI, _LOG_SQRT_2_OVER_PI)
#      <a href='file:///Users/evanrobert/anaconda3/envs/ESDL_LSTM/lib/python3.10/site-packages/scipy/stats/_continuous_distns.py?line=31'>32</a> from ._censored_data import CensoredData
# ---> <a href='file:///Users/evanrobert/anaconda3/envs/ESDL_LSTM/lib/python3.10/site-packages/scipy/stats/_continuous_distns.py?line=32'>33</a> import scipy.stats._boost as _boost
#      <a href='file:///Users/evanrobert/anaconda3/envs/ESDL_LSTM/lib/python3.10/site-packages/scipy/stats/_continuous_distns.py?line=33'>34</a> from scipy.optimize import root_scalar
#      <a href='file:///Users/evanrobert/anaconda3/envs/ESDL_LSTM/lib/python3.10/site-packages/scipy/stats/_continuous_distns.py?line=34'>35</a> from scipy.stats._warnings_errors import FitError
#
# File ~/anaconda3/envs/ESDL_LSTM/lib/python3.10/site-packages/scipy/stats/_boost/__init__.py:49
#      <a href='file:///Users/evanrobert/anaconda3/envs/ESDL_LSTM/lib/python3.10/site-packages/scipy/stats/_boost/__init__.py?line=36'>37</a> from scipy.stats._boost.nct_ufunc import (
#      <a href='file:///Users/evanrobert/anaconda3/envs/ESDL_LSTM/lib/python3.10/site-packages/scipy/stats/_boost/__init__.py?line=37'>38</a>     _nct_pdf, _nct_cdf, _nct_sf, _nct_ppf,
#      <a href='file:///Users/evanrobert/anaconda3/envs/ESDL_LSTM/lib/python3.10/site-packages/scipy/stats/_boost/__init__.py?line=38'>39</a>     _nct_isf, _nct_mean, _nct_variance,
#      <a href='file:///Users/evanrobert/anaconda3/envs/ESDL_LSTM/lib/python3.10/site-packages/scipy/stats/_boost/__init__.py?line=39'>40</a>     _nct_skewness, _nct_kurtosis_excess,
#      <a href='file:///Users/evanrobert/anaconda3/envs/ESDL_LSTM/lib/python3.10/site-packages/scipy/stats/_boost/__init__.py?line=40'>41</a> )
#      <a href='file:///Users/evanrobert/anaconda3/envs/ESDL_LSTM/lib/python3.10/site-packages/scipy/stats/_boost/__init__.py?line=42'>43</a> from scipy.stats._boost.skewnorm_ufunc import (
#      <a href='file:///Users/evanrobert/anaconda3/envs/ESDL_LSTM/lib/python3.10/site-packages/scipy/stats/_boost/__init__.py?line=43'>44</a>     _skewnorm_pdf, _skewnorm_cdf, _skewnorm_sf, _skewnorm_ppf,
#      <a href='file:///Users/evanrobert/anaconda3/envs/ESDL_LSTM/lib/python3.10/site-packages/scipy/stats/_boost/__init__.py?line=44'>45</a>     _skewnorm_isf, _skewnorm_mean, _skewnorm_variance,
#      <a href='file:///Users/evanrobert/anaconda3/envs/ESDL_LSTM/lib/python3.10/site-packages/scipy/stats/_boost/__init__.py?line=45'>46</a>     _skewnorm_skewness, _skewnorm_kurtosis_excess,
#      <a href='file:///Users/evanrobert/anaconda3/envs/ESDL_LSTM/lib/python3.10/site-packages/scipy/stats/_boost/__init__.py?line=46'>47</a> )
# ---> <a href='file:///Users/evanrobert/anaconda3/envs/ESDL_LSTM/lib/python3.10/site-packages/scipy/stats/_boost/__init__.py?line=48'>49</a> from scipy.stats._boost.invgauss_ufunc import (
#      <a href='file:///Users/evanrobert/anaconda3/envs/ESDL_LSTM/lib/python3.10/site-packages/scipy/stats/_boost/__init__.py?line=49'>50</a>     _invgauss_pdf, _invgauss_cdf, _invgauss_sf, _invgauss_ppf,
#      <a href='file:///Users/evanrobert/anaconda3/envs/ESDL_LSTM/lib/python3.10/site-packages/scipy/stats/_boost/__init__.py?line=50'>51</a>     _invgauss_isf, _invgauss_mean, _invgauss_variance,
#      <a href='file:///Users/evanrobert/anaconda3/envs/ESDL_LSTM/lib/python3.10/site-packages/scipy/stats/_boost/__init__.py?line=51'>52</a>     _invgauss_skewness, _invgauss_kurtosis_excess,
#      <a href='file:///Users/evanrobert/anaconda3/envs/ESDL_LSTM/lib/python3.10/site-packages/scipy/stats/_boost/__init__.py?line=52'>53</a> )
#
# File <frozen importlib._bootstrap>:404, in parent(self)
#
# KeyboardInterrupt:

# %%
import sys
sys.path.append('/Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/')

# %%
trainer = UCB_train.
