# %%
import sys
sys.path.append('/Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/')
from UCB_train import UCB_trainer
from pathlib import Path
import matplotlib.pyplot as plt
from neuralhydrology.evaluation.metrics import calculate_all_metrics
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
path_to_csv = Path('/Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/UCB_training')
params = {'learning_rate': 0.001, 'batch_size': 256, 'epochs': 1, 'validate_every': 1, 'save_weights_every': 1}
num_ensemble_members = 1
trainer = UCB_trainer(path_to_csv, params, num_ensemble_members)

# %%
trainer.train()
# Out:
# 2024-10-16 14:03:21,627: Logging to /Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_1610_140321/output.log initialized.
# 2024-10-16 14:03:21,628: ### Folder structure created at /Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_1610_140321
# 2024-10-16 14:03:21,628: ### Run configurations for testing_run
# 2024-10-16 14:03:21,629: experiment_name: testing_run
# 2024-10-16 14:03:21,630: train_basin_file: train_basin_file_template
# 2024-10-16 14:03:21,630: validation_basin_file: train_basin_file_template
# 2024-10-16 14:03:21,631: test_basin_file: train_basin_file_template
# 2024-10-16 14:03:21,633: train_start_date: 1981-10-01 00:00:00
# 2024-10-16 14:03:21,633: train_end_date: 1997-09-30 00:00:00
# 2024-10-16 14:03:21,634: validation_start_date: 1997-10-01 00:00:00
# 2024-10-16 14:03:21,634: validation_end_date: 2000-09-30 00:00:00
# 2024-10-16 14:03:21,635: test_start_date: 2000-10-01 00:00:00
# 2024-10-16 14:03:21,635: test_end_date: 2005-09-30 00:00:00
# 2024-10-16 14:03:21,636: device: cpu
# 2024-10-16 14:03:21,636: validate_every: 1
# 2024-10-16 14:03:21,637: validate_n_random_basins: 1
# 2024-10-16 14:03:21,637: metrics: ['NSE', 'MSE']
# 2024-10-16 14:03:21,638: model: cudalstm
# 2024-10-16 14:03:21,638: head: regression
# 2024-10-16 14:03:21,638: output_activation: linear
# 2024-10-16 14:03:21,639: hidden_size: 64
# 2024-10-16 14:03:21,641: initial_forget_bias: 3
# 2024-10-16 14:03:21,642: output_dropout: 0.5
# 2024-10-16 14:03:21,644: optimizer: Adam
# 2024-10-16 14:03:21,644: loss: MSE
# 2024-10-16 14:03:21,646: learning_rate: 0.001
# 2024-10-16 14:03:21,648: batch_size: 256
# 2024-10-16 14:03:21,649: epochs: 1
# 2024-10-16 14:03:21,650: clip_gradient_norm: 1
# 2024-10-16 14:03:21,651: predict_last_n: 1
# 2024-10-16 14:03:21,651: seq_length: 365
# 2024-10-16 14:03:21,651: num_workers: 8
# 2024-10-16 14:03:21,652: log_interval: 4
# 2024-10-16 14:03:21,652: log_tensorboard: True
# 2024-10-16 14:03:21,653: log_n_figures: 1
# 2024-10-16 14:03:21,653: save_weights_every: 1
# 2024-10-16 14:03:21,654: dataset: tuler
# 2024-10-16 14:03:21,654: data_dir: /Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/UCB_training
# 2024-10-16 14:03:21,654: dynamic_inputs: ['MF_TuleR_S10ET-POTENTIAL', 'MF_TuleR_S10FLOW', 'MF_TuleR_S10PRECIP-INC', 'MF_TuleR_S10SATURATION FRACTION', 'MF_TuleR_S10STORAGE-SOIL', 'MF_TuleR_S10SWE-OBSERVED', 'MF_TuleR_S10TEMPERATURE-AIR', 'MF_TuleR_S20ET-POTENTIAL', 'MF_TuleR_S20FLOW', 'MF_TuleR_S20PRECIP-INC', 'MF_TuleR_S20SATURATION FRACTION', 'MF_TuleR_S20STORAGE-SOIL', 'MF_TuleR_S20SWE-OBSERVED', 'MF_TuleR_S20TEMPERATURE-AIR', 'NF_TuleR_S10ET-POTENTIAL', 'NF_TuleR_S10FLOW', 'NF_TuleR_S10PRECIP-INC', 'NF_TuleR_S10SATURATION FRACTION', 'NF_TuleR_S10STORAGE-SOIL', 'NF_TuleR_S10SWE-OBSERVED', 'NF_TuleR_S10TEMPERATURE-AIR', 'ReservoirInflowFLOW', 'SF_TuleR_S10ET-POTENTIAL', 'SF_TuleR_S10FLOW', 'SF_TuleR_S10PRECIP-INC', 'SF_TuleR_S10SATURATION FRACTION', 'SF_TuleR_S10STORAGE-SOIL', 'SF_TuleR_S10SWE-OBSERVED', 'SF_TuleR_S10TEMPERATURE-AIR', 'TuleR_S10ET-POTENTIAL', 'TuleR_S10FLOW', 'TuleR_S10PRECIP-INC', 'TuleR_S10SATURATION FRACTION', 'TuleR_S10STORAGE-SOIL', 'TuleR_S10TEMPERATURE-AIR', 'TuleR_S20ET-POTENTIAL', 'TuleR_S20FLOW', 'TuleR_S20PRECIP-INC', 'TuleR_S20SATURATION FRACTION', 'TuleR_S20STORAGE-SOIL', 'TuleR_S20SWE-OBSERVED', 'TuleR_S20TEMPERATURE-AIR']
# 2024-10-16 14:03:21,655: target_variables: ['ReservoirInflowFLOW-OBSERVED']
# 2024-10-16 14:03:21,655: number_of_basins: 1
# 2024-10-16 14:03:21,656: run_dir: /Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_1610_140321
# 2024-10-16 14:03:21,656: train_dir: /Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_1610_140321/train_data
# 2024-10-16 14:03:21,657: img_log_dir: /Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_1610_140321/img_log
# 2024-10-16 14:03:21,665: ### Device cpu will be used for training
# 2024-10-16 14:03:21,667: Loading basin data into xarray data set.
# 100%|██████████| 1/1 [00:00<00:00,  9.75it/s]
# 2024-10-16 14:03:21,968: Create lookup table and convert to pytorch tensor
# 100%|██████████| 1/1 [00:01<00:00,  1.67s/it]
# # Epoch 1:   0%|          | 0/22 [00:00<?, ?it/s]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
trainer.results()
# Out:
# {'NSE': 0.4514201283454895,
#  'MSE': 28130.21875,
#  'RMSE': 167.72065689711567,
#  'KGE': 0.5651052431420207,
#  'Alpha-NSE': 0.7137478017832088,
#  'Beta-KGE': 0.9799897074699402,
#  'Beta-NSE': -0.012082123182617656,
#  'Pearson-r': 0.6732084506118965,
#  'FHV': -43.545711040496826,
#  'FMS': 99.70865157393753,
#  'FLV': -164.86268838985103,
#  'Peak-Timing': 0.42857142857142855,
#  'Peak-MAPE': 42.8872857775007}

# %%
# .311

# %%
path_to_csv = Path('/Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/UCB_training')
params = {'learning_rate': 0.001, 'batch_size': 256, 'epochs': 2, 'validate_every': 2, 'save_weights_every': 2}
num_ensemble_members = 3
trainer = UCB_trainer(path_to_csv, params, num_ensemble_members)

# %%
trainer.train()
# Out:
# 2024-10-15 23:50:11,921: Logging to /Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_1510_235011/output.log initialized.
# 2024-10-15 23:50:11,922: ### Folder structure created at /Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_1510_235011
# 2024-10-15 23:50:11,922: ### Run configurations for testing_run
# 2024-10-15 23:50:11,923: experiment_name: testing_run
# 2024-10-15 23:50:11,923: train_basin_file: train_basin_file_template
# 2024-10-15 23:50:11,923: validation_basin_file: train_basin_file_template
# 2024-10-15 23:50:11,924: test_basin_file: train_basin_file_template
# 2024-10-15 23:50:11,924: train_start_date: 1981-10-01 00:00:00
# 2024-10-15 23:50:11,925: train_end_date: 1997-09-30 00:00:00
# 2024-10-15 23:50:11,925: validation_start_date: 1997-10-01 00:00:00
# 2024-10-15 23:50:11,925: validation_end_date: 2000-09-30 00:00:00
# 2024-10-15 23:50:11,926: test_start_date: 2000-10-01 00:00:00
# 2024-10-15 23:50:11,926: test_end_date: 2005-09-30 00:00:00
# 2024-10-15 23:50:11,926: device: cpu
# 2024-10-15 23:50:11,927: validate_every: 2
# 2024-10-15 23:50:11,927: validate_n_random_basins: 1
# 2024-10-15 23:50:11,928: metrics: ['NSE', 'MSE']
# 2024-10-15 23:50:11,928: model: cudalstm
# 2024-10-15 23:50:11,928: head: regression
# 2024-10-15 23:50:11,929: output_activation: linear
# 2024-10-15 23:50:11,929: hidden_size: 64
# 2024-10-15 23:50:11,929: initial_forget_bias: 3
# 2024-10-15 23:50:11,930: output_dropout: 0.5
# 2024-10-15 23:50:11,930: optimizer: Adam
# 2024-10-15 23:50:11,930: loss: MSE
# 2024-10-15 23:50:11,931: learning_rate: 0.001
# 2024-10-15 23:50:11,931: batch_size: 256
# 2024-10-15 23:50:11,931: epochs: 2
# 2024-10-15 23:50:11,932: clip_gradient_norm: 1
# 2024-10-15 23:50:11,932: predict_last_n: 1
# 2024-10-15 23:50:11,932: seq_length: 365
# 2024-10-15 23:50:11,933: num_workers: 8
# 2024-10-15 23:50:11,933: log_interval: 4
# 2024-10-15 23:50:11,933: log_tensorboard: True
# 2024-10-15 23:50:11,934: log_n_figures: 1
# 2024-10-15 23:50:11,934: save_weights_every: 2
# 2024-10-15 23:50:11,934: dataset: tuler
# 2024-10-15 23:50:11,935: data_dir: /Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/UCB_training
# 2024-10-15 23:50:11,935: dynamic_inputs: ['MF_TuleR_S10ET-POTENTIAL', 'MF_TuleR_S10FLOW', 'MF_TuleR_S10PRECIP-INC', 'MF_TuleR_S10SATURATION FRACTION', 'MF_TuleR_S10STORAGE-SOIL', 'MF_TuleR_S10SWE-OBSERVED', 'MF_TuleR_S10TEMPERATURE-AIR', 'MF_TuleR_S20ET-POTENTIAL', 'MF_TuleR_S20FLOW', 'MF_TuleR_S20PRECIP-INC', 'MF_TuleR_S20SATURATION FRACTION', 'MF_TuleR_S20STORAGE-SOIL', 'MF_TuleR_S20SWE-OBSERVED', 'MF_TuleR_S20TEMPERATURE-AIR', 'NF_TuleR_S10ET-POTENTIAL', 'NF_TuleR_S10FLOW', 'NF_TuleR_S10PRECIP-INC', 'NF_TuleR_S10SATURATION FRACTION', 'NF_TuleR_S10STORAGE-SOIL', 'NF_TuleR_S10SWE-OBSERVED', 'NF_TuleR_S10TEMPERATURE-AIR', 'ReservoirInflowFLOW', 'SF_TuleR_S10ET-POTENTIAL', 'SF_TuleR_S10FLOW', 'SF_TuleR_S10PRECIP-INC', 'SF_TuleR_S10SATURATION FRACTION', 'SF_TuleR_S10STORAGE-SOIL', 'SF_TuleR_S10SWE-OBSERVED', 'SF_TuleR_S10TEMPERATURE-AIR', 'TuleR_S10ET-POTENTIAL', 'TuleR_S10FLOW', 'TuleR_S10PRECIP-INC', 'TuleR_S10SATURATION FRACTION', 'TuleR_S10STORAGE-SOIL', 'TuleR_S10TEMPERATURE-AIR', 'TuleR_S20ET-POTENTIAL', 'TuleR_S20FLOW', 'TuleR_S20PRECIP-INC', 'TuleR_S20SATURATION FRACTION', 'TuleR_S20STORAGE-SOIL', 'TuleR_S20SWE-OBSERVED', 'TuleR_S20TEMPERATURE-AIR']
# 2024-10-15 23:50:11,935: target_variables: ['ReservoirInflowFLOW-OBSERVED']
# 2024-10-15 23:50:11,936: number_of_basins: 1
# 2024-10-15 23:50:11,936: run_dir: /Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_1510_235011
# 2024-10-15 23:50:11,936: train_dir: /Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_1510_235011/train_data
# 2024-10-15 23:50:11,937: img_log_dir: /Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_1510_235011/img_log
# 2024-10-15 23:50:11,945: ### Device cpu will be used for training
# 2024-10-15 23:50:11,946: Loading basin data into xarray data set.
# 100%|██████████| 1/1 [00:00<00:00, 14.67it/s]
# 2024-10-15 23:50:12,027: Create lookup table and convert to pytorch tensor
# 100%|██████████| 1/1 [00:00<00:00,  5.22it/s]
# # Epoch 1:   0%|          | 0/22 [00:00<?, ?it/s]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:   5%|▍         | 1/22 [00:21<07:36, 21.75s/it, Loss: 1.0607]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:   9%|▉         | 2/22 [00:22<03:05,  9.29s/it, Loss: 0.4081]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  14%|█▎        | 3/22 [00:22<01:40,  5.28s/it, Loss: 0.4688]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  18%|█▊        | 4/22 [00:23<01:01,  3.42s/it, Loss: 0.7083]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  23%|██▎       | 5/22 [00:23<00:39,  2.33s/it, Loss: 0.5180]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  27%|██▋       | 6/22 [00:24<00:26,  1.67s/it, Loss: 0.2901]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  32%|███▏      | 7/22 [00:24<00:19,  1.30s/it, Loss: 0.2320]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  36%|███▋      | 8/22 [00:25<00:14,  1.05s/it, Loss: 0.3239]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  41%|████      | 9/22 [00:25<00:11,  1.18it/s, Loss: 0.1695]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  45%|████▌     | 10/22 [00:26<00:08,  1.37it/s, Loss: 0.2690]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  50%|█████     | 11/22 [00:26<00:07,  1.55it/s, Loss: 0.5678]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  55%|█████▍    | 12/22 [00:27<00:05,  1.70it/s, Loss: 0.8885]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  59%|█████▉    | 13/22 [00:27<00:04,  1.81it/s, Loss: 0.1471]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  64%|██████▎   | 14/22 [00:28<00:04,  1.83it/s, Loss: 0.1674]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  68%|██████▊   | 15/22 [00:28<00:03,  1.86it/s, Loss: 0.1064]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  73%|███████▎  | 16/22 [00:28<00:03,  1.95it/s, Loss: 0.3250]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  77%|███████▋  | 17/22 [00:29<00:02,  2.04it/s, Loss: 0.1640]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  82%|████████▏ | 18/22 [00:29<00:01,  2.18it/s, Loss: 0.1968]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  86%|████████▋ | 19/22 [00:30<00:01,  1.91it/s, Loss: 0.3460]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  91%|█████████ | 20/22 [00:31<00:01,  1.70it/s, Loss: 0.0693]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  95%|█████████▌| 21/22 [00:31<00:00,  1.75it/s, Loss: 0.1483]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1: 100%|██████████| 22/22 [00:34<00:00,  1.56s/it, Loss: 0.0739]
# 2024-10-15 23:50:46,615: Epoch 1 average loss: avg_loss: 0.34768, avg_total_loss: 0.34768
# # Epoch 2:   0%|          | 0/22 [00:00<?, ?it/s]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 2:   5%|▍         | 1/22 [00:23<08:06, 23.17s/it, Loss: 0.0991]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 2:   9%|▉         | 2/22 [00:23<03:15,  9.80s/it, Loss: 0.2672]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 2:  14%|█▎        | 3/22 [00:24<01:44,  5.51s/it, Loss: 0.4918]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 2:  18%|█▊        | 4/22 [00:24<01:02,  3.50s/it, Loss: 0.4689]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 2:  23%|██▎       | 5/22 [00:24<00:40,  2.39s/it, Loss: 0.1373]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 2:  27%|██▋       | 6/22 [00:25<00:28,  1.77s/it, Loss: 0.0944]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 2:  32%|███▏      | 7/22 [00:25<00:20,  1.37s/it, Loss: 0.1297]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 2:  36%|███▋      | 8/22 [00:26<00:15,  1.08s/it, Loss: 0.1087]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 2:  41%|████      | 9/22 [00:26<00:11,  1.11it/s, Loss: 0.8801]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 2:  45%|████▌     | 10/22 [00:27<00:09,  1.33it/s, Loss: 0.1664]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 2:  50%|█████     | 11/22 [00:27<00:07,  1.55it/s, Loss: 0.1648]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 2:  55%|█████▍    | 12/22 [00:28<00:05,  1.73it/s, Loss: 0.0720]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 2:  59%|█████▉    | 13/22 [00:28<00:04,  1.84it/s, Loss: 0.0720]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 2:  64%|██████▎   | 14/22 [00:29<00:04,  2.00it/s, Loss: 0.2488]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 2:  68%|██████▊   | 15/22 [00:29<00:03,  2.15it/s, Loss: 0.1215]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 2:  73%|███████▎  | 16/22 [00:29<00:02,  2.09it/s, Loss: 0.0801]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 2:  77%|███████▋  | 17/22 [00:30<00:02,  2.22it/s, Loss: 0.2310]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 2:  82%|████████▏ | 18/22 [00:30<00:01,  2.02it/s, Loss: 0.2387]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 2:  86%|████████▋ | 19/22 [00:31<00:01,  1.98it/s, Loss: 0.0819]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 2:  91%|█████████ | 20/22 [00:32<00:01,  1.90it/s, Loss: 0.1461]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 2:  95%|█████████▌| 21/22 [00:32<00:00,  1.90it/s, Loss: 0.5646]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 2: 100%|██████████| 22/22 [00:34<00:00,  1.56s/it, Loss: 0.1837]
# 2024-10-15 23:51:20,950: Epoch 2 average loss: avg_loss: 0.22949, avg_total_loss: 0.22949
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  1.35it/s]
# 2024-10-15 23:51:21,903: Epoch 2 average validation loss: 0.09525 -- Median validation metrics: avg_loss: 0.09525, NSE: 0.78379, MSE: 44841.07031
# 2024-10-15 23:51:21,906: Logging to /Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_1510_235011/testing_run_1510_235121/output.log initialized.
# 2024-10-15 23:51:21,907: ### Folder structure created at /Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_1510_235011/testing_run_1510_235121
# 2024-10-15 23:51:21,907: ### Run configurations for testing_run
# 2024-10-15 23:51:21,907: experiment_name: testing_run
# 2024-10-15 23:51:21,908: train_basin_file: train_basin_file_template
# 2024-10-15 23:51:21,908: validation_basin_file: train_basin_file_template
# 2024-10-15 23:51:21,908: test_basin_file: train_basin_file_template
# 2024-10-15 23:51:21,909: train_start_date: 1981-10-01 00:00:00
# 2024-10-15 23:51:21,909: train_end_date: 1997-09-30 00:00:00
# 2024-10-15 23:51:21,910: validation_start_date: 1997-10-01 00:00:00
# 2024-10-15 23:51:21,910: validation_end_date: 2000-09-30 00:00:00
# 2024-10-15 23:51:21,910: test_start_date: 2000-10-01 00:00:00
# 2024-10-15 23:51:21,911: test_end_date: 2005-09-30 00:00:00
# 2024-10-15 23:51:21,911: device: cpu
# 2024-10-15 23:51:21,911: validate_every: 2
# 2024-10-15 23:51:21,912: validate_n_random_basins: 1
# 2024-10-15 23:51:21,912: metrics: ['NSE', 'MSE']
# 2024-10-15 23:51:21,912: model: cudalstm
# 2024-10-15 23:51:21,912: head: regression
# 2024-10-15 23:51:21,913: output_activation: linear
# 2024-10-15 23:51:21,914: hidden_size: 64
# 2024-10-15 23:51:21,914: initial_forget_bias: 3
# 2024-10-15 23:51:21,915: output_dropout: 0.5
# 2024-10-15 23:51:21,916: optimizer: Adam
# 2024-10-15 23:51:21,918: loss: MSE
# 2024-10-15 23:51:21,919: learning_rate: 0.001
# 2024-10-15 23:51:21,920: batch_size: 256
# 2024-10-15 23:51:21,923: epochs: 2
# 2024-10-15 23:51:21,926: clip_gradient_norm: 1
# 2024-10-15 23:51:21,929: predict_last_n: 1
# 2024-10-15 23:51:21,930: seq_length: 365
# 2024-10-15 23:51:21,932: num_workers: 8
# 2024-10-15 23:51:21,935: log_interval: 4
# 2024-10-15 23:51:21,940: log_tensorboard: True
# 2024-10-15 23:51:21,941: log_n_figures: 1
# 2024-10-15 23:51:21,942: save_weights_every: 2
# 2024-10-15 23:51:21,944: dataset: tuler
# 2024-10-15 23:51:21,945: data_dir: /Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/UCB_training
# 2024-10-15 23:51:21,946: dynamic_inputs: ['MF_TuleR_S10ET-POTENTIAL', 'MF_TuleR_S10FLOW', 'MF_TuleR_S10PRECIP-INC', 'MF_TuleR_S10SATURATION FRACTION', 'MF_TuleR_S10STORAGE-SOIL', 'MF_TuleR_S10SWE-OBSERVED', 'MF_TuleR_S10TEMPERATURE-AIR', 'MF_TuleR_S20ET-POTENTIAL', 'MF_TuleR_S20FLOW', 'MF_TuleR_S20PRECIP-INC', 'MF_TuleR_S20SATURATION FRACTION', 'MF_TuleR_S20STORAGE-SOIL', 'MF_TuleR_S20SWE-OBSERVED', 'MF_TuleR_S20TEMPERATURE-AIR', 'NF_TuleR_S10ET-POTENTIAL', 'NF_TuleR_S10FLOW', 'NF_TuleR_S10PRECIP-INC', 'NF_TuleR_S10SATURATION FRACTION', 'NF_TuleR_S10STORAGE-SOIL', 'NF_TuleR_S10SWE-OBSERVED', 'NF_TuleR_S10TEMPERATURE-AIR', 'ReservoirInflowFLOW', 'SF_TuleR_S10ET-POTENTIAL', 'SF_TuleR_S10FLOW', 'SF_TuleR_S10PRECIP-INC', 'SF_TuleR_S10SATURATION FRACTION', 'SF_TuleR_S10STORAGE-SOIL', 'SF_TuleR_S10SWE-OBSERVED', 'SF_TuleR_S10TEMPERATURE-AIR', 'TuleR_S10ET-POTENTIAL', 'TuleR_S10FLOW', 'TuleR_S10PRECIP-INC', 'TuleR_S10SATURATION FRACTION', 'TuleR_S10STORAGE-SOIL', 'TuleR_S10TEMPERATURE-AIR', 'TuleR_S20ET-POTENTIAL', 'TuleR_S20FLOW', 'TuleR_S20PRECIP-INC', 'TuleR_S20SATURATION FRACTION', 'TuleR_S20STORAGE-SOIL', 'TuleR_S20SWE-OBSERVED', 'TuleR_S20TEMPERATURE-AIR']
# 2024-10-15 23:51:21,947: target_variables: ['ReservoirInflowFLOW-OBSERVED']
# 2024-10-15 23:51:21,951: number_of_basins: 1
# 2024-10-15 23:51:21,956: run_dir: /Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_1510_235011/testing_run_1510_235121
# 2024-10-15 23:51:21,958: train_dir: /Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_1510_235011/testing_run_1510_235121/train_data
# 2024-10-15 23:51:21,960: img_log_dir: /Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_1510_235011/testing_run_1510_235121/img_log
# 2024-10-15 23:51:21,961: seed: 657616
# 2024-10-15 23:51:21,963: commit_hash: 664b851
# 2024-10-15 23:51:21,964: package_version: 1.11.0
# 2024-10-15 23:51:21,977: ### Device cpu will be used for training
# 2024-10-15 23:51:21,980: Loading basin data into xarray data set.
# 100%|██████████| 1/1 [00:00<00:00, 11.51it/s]
# 2024-10-15 23:51:22,087: Create lookup table and convert to pytorch tensor
# 100%|██████████| 1/1 [00:00<00:00,  4.84it/s]
# # Epoch 1:   0%|          | 0/22 [00:00<?, ?it/s]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:   5%|▍         | 1/22 [00:20<07:15, 20.74s/it, Loss: 1.0607]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:   9%|▉         | 2/22 [00:21<02:56,  8.80s/it, Loss: 0.4081]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  14%|█▎        | 3/22 [00:21<01:34,  4.96s/it, Loss: 0.4688]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  18%|█▊        | 4/22 [00:21<00:56,  3.16s/it, Loss: 0.7083]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  23%|██▎       | 5/22 [00:22<00:36,  2.17s/it, Loss: 0.5180]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  27%|██▋       | 6/22 [00:22<00:25,  1.57s/it, Loss: 0.2901]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  32%|███▏      | 7/22 [00:23<00:17,  1.18s/it, Loss: 0.2320]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  36%|███▋      | 8/22 [00:23<00:12,  1.08it/s, Loss: 0.3239]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  41%|████      | 9/22 [00:23<00:09,  1.32it/s, Loss: 0.1695]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  45%|████▌     | 10/22 [00:24<00:07,  1.56it/s, Loss: 0.2690]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  50%|█████     | 11/22 [00:24<00:06,  1.74it/s, Loss: 0.5678]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  55%|█████▍    | 12/22 [00:25<00:05,  1.94it/s, Loss: 0.8885]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  59%|█████▉    | 13/22 [00:25<00:04,  2.09it/s, Loss: 0.1471]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  64%|██████▎   | 14/22 [00:25<00:03,  2.20it/s, Loss: 0.1674]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  68%|██████▊   | 15/22 [00:26<00:03,  2.32it/s, Loss: 0.1064]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  73%|███████▎  | 16/22 [00:26<00:02,  2.36it/s, Loss: 0.3250]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  77%|███████▋  | 17/22 [00:27<00:02,  2.41it/s, Loss: 0.1640]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  82%|████████▏ | 18/22 [00:27<00:01,  2.47it/s, Loss: 0.1968]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  86%|████████▋ | 19/22 [00:27<00:01,  2.50it/s, Loss: 0.3460]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  91%|█████████ | 20/22 [00:28<00:00,  2.56it/s, Loss: 0.0693]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  95%|█████████▌| 21/22 [00:28<00:00,  2.57it/s, Loss: 0.1483]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1: 100%|██████████| 22/22 [00:29<00:00,  1.36s/it, Loss: 0.0739]
# 2024-10-15 23:51:52,292: Epoch 1 average loss: avg_loss: 0.34768, avg_total_loss: 0.34768
# # Epoch 2:   0%|          | 0/22 [00:00<?, ?it/s]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 2:   5%|▍         | 1/22 [00:20<07:11, 20.56s/it, Loss: 0.0991]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 2:   9%|▉         | 2/22 [00:20<02:54,  8.70s/it, Loss: 0.2672]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# ...
# # Epoch 1:  73%|███████▎  | 16/22 [00:27<00:02,  2.31it/s, Loss: 0.3250]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  77%|███████▋  | 17/22 [00:27<00:02,  2.29it/s, Loss: 0.1640]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  82%|████████▏ | 18/22 [00:28<00:01,  2.32it/s, Loss: 0.1968]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  86%|████████▋ | 19/22 [00:28<00:01,  2.33it/s, Loss: 0.3460]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  91%|█████████ | 20/22 [00:29<00:00,  2.27it/s, Loss: 0.0693]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:  95%|█████████▌| 21/22 [00:29<00:00,  2.20it/s, Loss: 0.1483]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1: 100%|██████████| 22/22 [00:31<00:00,  1.42s/it, Loss: 0.0739]
# 2024-10-15 23:52:54,613: Epoch 1 average loss: avg_loss: 0.34768, avg_total_loss: 0.34768
# # Epoch 2:   0%|          | 0/22 [00:00<?, ?it/s]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 2:   5%|▍         | 1/22 [00:20<07:15, 20.76s/it, Loss: 0.0991]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 2:   9%|▉         | 2/22 [00:21<02:58,  8.91s/it, Loss: 0.2672]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 2:  14%|█▎        | 3/22 [00:21<01:35,  5.01s/it, Loss: 0.4918]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 2:  18%|█▊        | 4/22 [00:22<00:57,  3.21s/it, Loss: 0.4689]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 2:  23%|██▎       | 5/22 [00:22<00:37,  2.21s/it, Loss: 0.1373]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 2:  27%|██▋       | 6/22 [00:23<00:26,  1.66s/it, Loss: 0.0944]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 2:  32%|███▏      | 7/22 [00:23<00:19,  1.31s/it, Loss: 0.1297]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 2:  36%|███▋      | 8/22 [00:24<00:14,  1.02s/it, Loss: 0.1087]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 2:  41%|████      | 9/22 [00:24<00:11,  1.12it/s, Loss: 0.8801]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 2:  45%|████▌     | 10/22 [00:25<00:09,  1.27it/s, Loss: 0.1664]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 2:  50%|█████     | 11/22 [00:25<00:07,  1.41it/s, Loss: 0.1648]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 2:  55%|█████▍    | 12/22 [00:26<00:06,  1.57it/s, Loss: 0.0720]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 2:  59%|█████▉    | 13/22 [00:26<00:05,  1.75it/s, Loss: 0.0720]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 2:  64%|██████▎   | 14/22 [00:27<00:04,  1.93it/s, Loss: 0.2488]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 2:  68%|██████▊   | 15/22 [00:27<00:03,  2.09it/s, Loss: 0.1215]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 2:  73%|███████▎  | 16/22 [00:27<00:02,  2.19it/s, Loss: 0.0801]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 2:  77%|███████▋  | 17/22 [00:28<00:02,  2.28it/s, Loss: 0.2310]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 2:  82%|████████▏ | 18/22 [00:28<00:01,  2.38it/s, Loss: 0.2387]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 2:  86%|████████▋ | 19/22 [00:29<00:01,  2.45it/s, Loss: 0.0819]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 2:  91%|█████████ | 20/22 [00:29<00:00,  2.49it/s, Loss: 0.1461]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 2:  95%|█████████▌| 21/22 [00:29<00:00,  2.49it/s, Loss: 0.5646]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 2: 100%|██████████| 22/22 [00:31<00:00,  1.42s/it, Loss: 0.1837]
# 2024-10-15 23:53:25,835: Epoch 2 average loss: avg_loss: 0.22949, avg_total_loss: 0.22949
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  1.36it/s]
# 2024-10-15 23:53:26,783: Epoch 2 average validation loss: 0.09525 -- Median validation metrics: avg_loss: 0.09525, NSE: 0.78379, MSE: 44841.07031
# 2024-10-15 23:53:26,813: Using the model weights from /Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_1510_235011/model_epoch002.pt
# # Evaluation: 100%|██████████| 1/1 [00:01<00:00,  1.14s/it]
# 2024-10-15 23:53:27,961: Stored metrics at /Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_1510_235011/test/model_epoch002/test_metrics.csv
# 2024-10-15 23:53:27,962: Stored results at /Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_1510_235011/test/model_epoch002/test_results.p
# 2024-10-15 23:53:27,989: Using the model weights from /Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_1510_235011/testing_run_1510_235121/model_epoch002.pt
# # Evaluation: 100%|██████████| 1/1 [00:01<00:00,  1.23s/it]
# 2024-10-15 23:53:29,242: Stored metrics at /Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_1510_235011/testing_run_1510_235121/test/model_epoch002/test_metrics.csv
# 2024-10-15 23:53:29,243: Stored results at /Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_1510_235011/testing_run_1510_235121/test/model_epoch002/test_results.p
# 2024-10-15 23:53:29,263: Using the model weights from /Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_1510_235011/testing_run_1510_235121/testing_run_1510_235222/model_epoch002.pt
# # Evaluation: 100%|██████████| 1/1 [00:01<00:00,  1.15s/it]
# 2024-10-15 23:53:30,424: Stored metrics at /Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_1510_235011/testing_run_1510_235121/testing_run_1510_235222/test/model_epoch002/test_metrics.csv
# 2024-10-15 23:53:30,425: Stored results at /Users/evanrobert/Documents/ESDL_Research/russian_river/UCB-USACE-LSTMs/neuralhydrology/UCB_training/runs/testing_run_1510_235011/testing_run_1510_235121/testing_run_1510_235222/test/model_epoch002/test_results.p
# Loading results for each run.
# 100%|██████████| 3/3 [00:00<00:00, 1061.22it/s]
# Combining results and calculating metrics.
# 100%|██████████| 1/1 [00:00<00:00, 88.19it/s]

# %%
trainer.results()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 trainer.results()
#
# NameError: name 'trainer' is not defined

# %%
trainer.test
